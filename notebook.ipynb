# %% [markdown]
# # mtcars
#
# In this notebook, you'll explore the iconic `mtcars` dataset. Why mtcars? Because it is a classic pedagogical dataset and there is A LOT written about it online. Every complicated concept we encounter, you should be able to google the name plus `mtcars` and find some information about it. So for example, when we study linear regression, you'll be able to google "linear regression mtcars" and find a million billion tutorials that use this dataset to teach regressions. It will give us a common vocabulary with other learners around the world.

# %% [markdown]
# ### Standard Python and R imports

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# # My commonly used R imports
#
# require('tidyverse')

# %%
# EXAMPLE PYTHON CELL

df = pd.DataFrame(
    np.random.randint(0,100,size=(100, 2)), columns=list('AB'))
df.head()
# Out:
#     A   B
# 0  58  33
# 1  99  60
# 2  17  69
# 3   5  61
# 4  77  44

# %%
# %%R -i df
#
# # EXAMPLE R CELL
# df
# plt <- ggplot(df) +
#     geom_point(aes(A,B))
#
# plt

# %% [markdown]
# ## Load the data

# %%
# %%R
#
# # Import data with R
# mtcars <- read_csv('mtcars.csv', show_col_types = FALSE)
# mtcars %>% head(4)
# Out:
# # A tibble: 4 × 12
#   name           mpg   cyl  disp    hp  drat    wt  qsec    vs    am  gear  carb
#   <chr>        <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl>
# 1 Mazda RX4     21       6   160   110  3.9   2.62  16.5     0     1     4     4
# 2 Mazda RX4 W…  21       6   160   110  3.9   2.88  17.0     0     1     4     4
# 3 Datsun 710    22.8     4   108    93  3.85  2.32  18.6     1     1     4     1
# 4 Hornet 4 Dr…  21.4     6   258   110  3.08  3.22  19.4     1     0     3     1

# %%
# Import data in python
mtcars = pd.read_csv('mtcars.csv')
mtcars.head()
# Out:
#                 name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
# !/usr/bin/env RScript
# Out:
# Usage: Rscript [options] file [args]
#    or: Rscript [options] -e expr [-e expr2 ...] [args]
# A binary front-end to R, for use in scripting applications.
#
# Options:
#   --help              Print usage and exit
#   --version           Print version and exit
#   --verbose           Print information on progress
#   --default-packages=LIST  Attach these packages on startup;
#                         a comma-separated LIST of package names, or 'NULL'
# and options to R (in addition to --no-echo --no-restore), for example:
#   --save              Do save workspace at the end of the session
#   --no-environ        Don't read the site and user environment files
#   --no-site-file      Don't read the site-wide Rprofile
#   --no-init-file      Don't read the user R profile
#   --restore           Do restore previously saved objects at startup
#   --vanilla           Combine --no-save, --no-restore, --no-site-file,
#                         --no-init-file and --no-environ
#
# Expressions (one or more '-e <expr>') may be used *instead* of 'file'.
# Any additional 'args' can be accessed from R via 'commandArgs(TRUE)'.
# See also  ?Rscript  from within R.

# %%
# %%R
#
# installPackage <- function(pkg) {install.packages(pkg, repos='http://cran.us.r-project.org', verbose = TRUE)}

# %%
# %%R
# libs <- c("tidyverse", "extrafont", "Cairo", "devtools","gridExtra")

# %%
# %%R
#
# lapply(libs, installPackage)
# Out:
# R[write to console]: Installing package into ‘/opt/homebrew/lib/R/4.2/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: system (cmd0): /opt/homebrew/Cellar/r/4.2.2_1/lib/R/bin/R CMD INSTALL
#
# R[write to console]: trying URL 'http://cran.us.r-project.org/src/contrib/tidyverse_1.3.2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 702514 bytes (686 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 686 KB
#
#
# R[write to console]: foundpkgs: tidyverse, /var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T//RtmplJ9GEe/downloaded_packages/tidyverse_1.3.2.tar.gz
#
# R[write to console]: files: /var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T//RtmplJ9GEe/downloaded_packages/tidyverse_1.3.2.tar.gz
#
# * installing *source* package ‘tidyverse’ ...
# ** package ‘tidyverse’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (tidyverse)
# R[write to console]: 1): succeeded '/opt/homebrew/Cellar/r/4.2.2_1/lib/R/bin/R CMD INSTALL -l '/opt/homebrew/lib/R/4.2/site-library' '/var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T//RtmplJ9GEe/downloaded_packages/tidyverse_1.3.2.tar.gz''
#
# R[write to console]:
#
# R[write to console]:
# R[write to console]: The downloaded source packages are in
# 	‘/private/var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T/RtmplJ9GEe/downloaded_packages’
# R[write to console]:
# R[write to console]:
#
# R[write to console]: Installing package into ‘/opt/homebrew/lib/R/4.2/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: system (cmd0): /opt/homebrew/Cellar/r/4.2.2_1/lib/R/bin/R CMD INSTALL
#
# R[write to console]: trying URL 'http://cran.us.r-project.org/src/contrib/extrafont_0.19.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 16533 bytes (16 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 16 KB
#
#
# R[write to console]: foundpkgs: extrafont, /var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T//RtmplJ9GEe/downloaded_packages/extrafont_0.19.tar.gz
#
# R[write to console]: files: /var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T//RtmplJ9GEe/downloaded_packages/extrafont_0.19.tar.gz
#
# * installing *source* package ‘extrafont’ ...
# ** package ‘extrafont’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (extrafont)
# R[write to console]: 1): succeeded '/opt/homebrew/Cellar/r/4.2.2_1/lib/R/bin/R CMD INSTALL -l '/opt/homebrew/lib/R/4.2/site-library' '/var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T//RtmplJ9GEe/downloaded_packages/extrafont_0.19.tar.gz''
#
# R[write to console]:
#
# R[write to console]:
# R[write to console]: The downloaded source packages are in
# 	‘/private/var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T/RtmplJ9GEe/downloaded_packages’
# R[write to console]:
# R[write to console]:
#
# R[write to console]: Installing package into ‘/opt/homebrew/lib/R/4.2/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: system (cmd0): /opt/homebrew/Cellar/r/4.2.2_1/lib/R/bin/R CMD INSTALL
#
# R[write to console]: trying URL 'http://cran.us.r-project.org/src/contrib/Cairo_1.6-0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 98278 bytes (95 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 95 KB
#
#
# R[write to console]: foundpkgs: Cairo, /var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T//RtmplJ9GEe/downloaded_packages/Cairo_1.6-0.tar.gz
#
# R[write to console]: files: /var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T//RtmplJ9GEe/downloaded_packages/Cairo_1.6-0.tar.gz
#
# * installing *source* package ‘Cairo’ ...
# ** package ‘Cairo’ successfully unpacked and MD5 sums checked
# ** using staged installation
# checking for gcc... clang
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether the compiler supports GNU C... yes
# checking whether clang accepts -g... yes
# checking for clang option to enable C11 features... none needed
# checking for sys/wait.h that is POSIX.1 compatible... yes
# checking for stdio.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for strings.h... yes
# checking for sys/stat.h... yes
# checking for sys/types.h... yes
# checking for unistd.h... yes
# checking for string.h... (cached) yes
# checking for sys/time.h... yes
# checking for unistd.h... (cached) yes
# checking for an ANSI C-conforming const... yes
# checking for pkg-config... /opt/homebrew/bin/pkg-config
# checking whether pkg-config knows about cairo... yes
# checking for configurable backends... cairo cairo-ft cairo-pdf cairo-png cairo-ps cairo-xlib cairo-xlib-xrender
# checking whether --static is needed... no
# configure: CAIRO_CFLAGS=-I/opt/homebrew/Cellar/cairo/1.16.0_5/include/cairo -I/opt/homebrew/Cellar/glib/2.74.5/include -I/opt/homebrew/Cellar/glib/2.74.5/include/glib-2.0 -I/opt/homebrew/Cellar/glib/2.74.5/lib/glib-2.0/include -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/Cellar/pcre2/10.42/include -I/opt/homebrew/Cellar/pixman/0.42.2/include/pixman-1 -I/opt/homebrew/Cellar/fontconfig/2.14.1/include -I/opt/homebrew/opt/freetype/include/freetype2 -I/opt/homebrew/Cellar/libpng/1.6.39/include/libpng16 -I/opt/homebrew/Cellar/libxcb/1.15/include -I/opt/homebrew/Cellar/libxext/1.3.5/include -I/opt/homebrew/Cellar/libxrender/0.9.11/include -I/opt/homebrew/Cellar/libx11/1.8.3/include -I/opt/homebrew/Cellar/libxcb/1.15/include -I/opt/homebrew/Cellar/libxau/1.0.11/include -I/opt/homebrew/Cellar/libxdmcp/1.1.4/include -I/opt/homebrew/Cellar/xorgproto/2022.2/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX13.sdk/usr/include/ffi
# checking if R was compiled with the RConn patch... no
# checking for cairo.h... yes
# checking for PNG support in Cairo... yes
# checking for ATS font support in Cairo... no
# configure: CAIRO_LIBS=-L/opt/homebrew/opt/freetype/lib -L/opt/homebrew/Cellar/libpng/1.6.39/lib -L/opt/homebrew/Cellar/cairo/1.16.0_5/lib -L/opt/homebrew/Cellar/libxext/1.3.5/lib -L/opt/homebrew/Cellar/libxrender/0.9.11/lib -L/opt/homebrew/Cellar/libx11/1.8.3/lib -lfreetype -lz -lpng16 -lz -lcairo -lXext -lXrender -lX11
# checking for library containing deflate... none required
# checking whether Cairo programs can be compiled... yes
# checking for clang options needed to detect all undeclared functions... -fno-builtin
# checking whether cairo_image_surface_get_format is declared... no
# checking whether FreeType support is desired... auto
# checking for FreeType support in cairo... yes
# checking whether FreeType needs additional flags... no
# checking whether libjpeg works... yes
# checking whether Harfbuzz layout is desired... auto
# checking whether Harfbuzz + ICU works... no
# checking whether libtiff works... no
# configure: creating ./config.status
# Package harfbuzz-icu was not found in the pkg-config search path.
# Perhaps you should add the directory containing `harfbuzz-icu.pc'
# to the PKG_CONFIG_PATH environment variable
# No package 'harfbuzz-icu' found
# Package icu-uc was not found in the pkg-config search path.
# Perhaps you should add the directory containing `icu-uc.pc'
# to the PKG_CONFIG_PATH environment variable
# No package 'icu-uc' found
# Package harfbuzz-icu was not found in the pkg-config search path.
# Perhaps you should add the directory containing `harfbuzz-icu.pc'
# to the PKG_CONFIG_PATH environment variable
# No package 'harfbuzz-icu' found
# Package icu-uc was not found in the pkg-config search path.
# Perhaps you should add the directory containing `icu-uc.pc'
# to the PKG_CONFIG_PATH environment variable
# No package 'icu-uc' found
# Package libtiff-4 was not found in the pkg-config search path.
# Perhaps you should add the directory containing `libtiff-4.pc'
# to the PKG_CONFIG_PATH environment variable
# No package 'libtiff-4' found
# config.status: creating src/Makevars
# config.status: creating src/cconfig.h
# clang -I"/opt/homebrew/Cellar/r/4.2.2_1/lib/R/include" -DNDEBUG -I/opt/homebrew/Cellar/cairo/1.16.0_5/include/cairo -I/opt/homebrew/Cellar/glib/2.74.5/include -I/opt/homebrew/Cellar/glib/2.74.5/include/glib-2.0 -I/opt/homebrew/Cellar/glib/2.74.5/lib/glib-2.0/include -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/Cellar/pcre2/10.42/include -I/opt/homebrew/Cellar/pixman/0.42.2/include/pixman-1 -I/opt/homebrew/Cellar/fontconfig/2.14.1/include -I/opt/homebrew/opt/freetype/include/freetype2 -I/opt/homebrew/Cellar/libpng/1.6.39/include/libpng16 -I/opt/homebrew/Cellar/libxcb/1.15/include -I/opt/homebrew/Cellar/libxext/1.3.5/include -I/opt/homebrew/Cellar/libxrender/0.9.11/include -I/opt/homebrew/Cellar/libx11/1.8.3/include -I/opt/homebrew/Cellar/libxcb/1.15/include -I/opt/homebrew/Cellar/libxau/1.0.11/include -I/opt/homebrew/Cellar/libxdmcp/1.1.4/include -I/opt/homebrew/Cellar/xorgproto/2022.2/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX13.sdk/usr/include/ffi   -I. -Iinclude  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include  -Wno-implicit-function-declaration -fPIC  -Wno-implicit-function-declaration  -c cairobem.c -o cairobem.o
# clang -I"/opt/homebrew/Cellar/r/4.2.2_1/lib/R/include" -DNDEBUG -I/opt/homebrew/Cellar/cairo/1.16.0_5/include/cairo -I/opt/homebrew/Cellar/glib/2.74.5/include -I/opt/homebrew/Cellar/glib/2.74.5/include/glib-2.0 -I/opt/homebrew/Cellar/glib/2.74.5/lib/glib-2.0/include -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/Cellar/pcre2/10.42/include -I/opt/homebrew/Cellar/pixman/0.42.2/include/pixman-1 -I/opt/homebrew/Cellar/fontconfig/2.14.1/include -I/opt/homebrew/opt/freetype/include/freetype2 -I/opt/homebrew/Cellar/libpng/1.6.39/include/libpng16 -I/opt/homebrew/Cellar/libxcb/1.15/include -I/opt/homebrew/Cellar/libxext/1.3.5/include -I/opt/homebrew/Cellar/libxrender/0.9.11/include -I/opt/homebrew/Cellar/libx11/1.8.3/include -I/opt/homebrew/Cellar/libxcb/1.15/include -I/opt/homebrew/Cellar/libxau/1.0.11/include -I/opt/homebrew/Cellar/libxdmcp/1.1.4/include -I/opt/homebrew/Cellar/xorgproto/2022.2/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX13.sdk/usr/include/ffi   -I. -Iinclude  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include  -Wno-implicit-function-declaration -fPIC  -Wno-implicit-function-declaration  -c cairogd.c -o cairogd.o
# clang -I"/opt/homebrew/Cellar/r/4.2.2_1/lib/R/include" -DNDEBUG -I/opt/homebrew/Cellar/cairo/1.16.0_5/include/cairo -I/opt/homebrew/Cellar/glib/2.74.5/include -I/opt/homebrew/Cellar/glib/2.74.5/include/glib-2.0 -I/opt/homebrew/Cellar/glib/2.74.5/lib/glib-2.0/include -I/opt/homebrew/opt/gettext/include -I/opt/homebrew
I/opt/homebrew/opt/gettext/include -I/opt/homebrew/Cellar/pcre2/10.42/include -I/opt/homebrew/Cellar/pixman/0.42.2/include/pixman-1 -I/opt/homebrew/Cellar/fontconfig/2.14.1/include -I/opt/homebrew/opt/freetype/include/freetype2 -I/opt/homebrew/Cellar/libpng/1.6.39/include/libpng16 -I/opt/homebrew/Cellar/libxcb/1.15/include -I/opt/homebrew/Cellar/libxext/1.3.5/include -I/opt/homebrew/Cellar/libxrender/0.9.11/include -I/opt/homebrew/Cellar/libx11/1.8.3/include -I/opt/homebrew/Cellar/libxcb/1.15/include -I/opt/homebrew/Cellar/libxau/1.0.11/include -I/opt/homebrew/Cellar/libxdmcp/1.1.4/include -I/opt/homebrew/Cellar/xorgproto/2022.2/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX13.sdk/usr/include/ffi   -I. -Iinclude  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include  -Wno-implicit-function-declaration -fPIC  -Wno-implicit-function-declaration  -c w32-backend.c -o w32-backend.o
# xlib-backend.c:34:10: fatal error: 'X11/Intrinsic.h' file not found
# #include <X11/Intrinsic.h>      /*->    Xlib.h  Xutil.h Xresource.h .. */
#          ^~~~~~~~~~~~~~~~~
# 1 error generated.
# make: *** [xlib-backend.o] Error 1
# ERROR: compilation failed for package ‘Cairo’
# * removing ‘/opt/homebrew/lib/R/4.2/site-library/Cairo’
# R[write to console]:
#
# R[write to console]:
# R[write to console]: The downloaded source packages are in
# 	‘/private/var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T/RtmplJ9GEe/downloaded_packages’
# R[write to console]:
# R[write to console]:
#
# R[write to console]: Installing package into ‘/opt/homebrew/lib/R/4.2/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: system (cmd0): /opt/homebrew/Cellar/r/4.2.2_1/lib/R/bin/R CMD INSTALL
# clang -I"/opt/homebrew/Cellar/r/4.2.2_1/lib/R/include" -DNDEBUG -I/opt/homebrew/Cellar/cairo/1.16.0_5/include/cairo -I/opt/homebrew/Cellar/glib/2.74.5/include -I/opt/homebrew/Cellar/glib/2.74.5/include/glib-2.0 -I/opt/homebrew/Cellar/glib/2.74.5/lib/glib-2.0/include -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/Cellar/pcre2/10.42/include -I/opt/homebrew/Cellar/pixman/0.42.2/include/pixman-1 -I/opt/homebrew/Cellar/fontconfig/2.14.1/include -I/opt/homebrew/opt/freetype/include/freetype2 -I/opt/homebrew/Cellar/libpng/1.6.39/include/libpng16 -I/opt/homebrew/Cellar/libxcb/1.15/include -I/opt/homebrew/Cellar/libxext/1.3.5/include -I/opt/homebrew/Cellar/libxrender/0.9.11/include -I/opt/homebrew/Cellar/libx11/1.8.3/include -I/opt/homebrew/Cellar/libxcb/1.15/include -I/opt/homebrew/Cellar/libxau/1.0.11/include -I/opt/homebrew/Cellar/libxdmcp/1.1.4/include -I/opt/homebrew/Cellar/xorgproto/2022.2/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX13.sdk/usr/include/ffi   -I. -Iinclude  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include  -Wno-implicit-function-declaration -fPIC  -Wno-implicit-function-declaration  -c xlib-backend.c -o xlib-backend.o
# R[write to console]: also installing the dependencies ‘textshaping’, ‘ragg’, ‘pkgdown’
#
#
# R[write to console]: trying URL 'http://cran.us.r-project.org/src/contrib/textshaping_0.3.6.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 35722 bytes (34 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 34 KB
#
#
# R[write to console]: trying URL 'http://cran.us.r-project.org/src/contrib/ragg_1.2.5.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 427859 bytes (417 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 417 KB
#
#
# R[write to console]: trying URL 'http://cran.us.r-project.org/src/contrib/pkgdown_2.0.7.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 871465 bytes (851 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 851 KB
#
#
# R[write to console]: trying URL 'http://cran.us.r-project.org/src/contrib/devtools_2.4.5.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 374718 bytes (365 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 365 KB
#
#
# R[write to console]: foundpkgs: textshaping, ragg, pkgdown, devtools, /var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T//RtmplJ9GEe/downloaded_packages/textshaping_0.3.6.tar.gz, /var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T//RtmplJ9GEe/downloaded_packages/ragg_1.2.5.tar.gz, /var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T//RtmplJ9GEe/downloaded_packages/pkgdown_2.0.7.tar.gz, /var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T//RtmplJ9GEe/downloaded_packages/devtools_2.4.5.tar.gz
#
# R[write to console]: files: /var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T//RtmplJ9GEe/downloaded_packages/textshaping_0.3.6.tar.gz,
# 	/var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T//RtmplJ9GEe/downloaded_packages/ragg_1.2.5.tar.gz,
# 	/var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T//RtmplJ9GEe/downloaded_packages/pkgdown_2.0.7.tar.gz,
# 	/var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T//RtmplJ9GEe/downloaded_packages/devtools_2.4.5.tar.gz
#
# * installing *source* package ‘textshaping’ ...
# ** package ‘textshaping’ successfully unpacked and MD5 sums checked
# ** using staged installation
# Package harfbuzz was not found in the pkg-config search path.
# Perhaps you should add the directory containing `harfbuzz.pc'
# to the PKG_CONFIG_PATH environment variable
# No package 'harfbuzz' found
# Package fribidi was not found in the pkg-config search path.
# Perhaps you should add the directory containing `fribidi.pc'
# to the PKG_CONFIG_PATH environment variable
# No package 'fribidi' found
# Homebrew 3.6.21
# Homebrew/homebrew-core (git revision 66e600d9e6a; last commit 2023-02-08)
# Using PKG_CFLAGS=-I/opt/homebrew/include/freetype2 -I/opt/homebrew/include/harfbuzz -I/opt/homebrew/include/glib-2.0  -I/opt/homebrew/include/fribidi
# Using PKG_LIBS=-lfreetype -lharfbuzz -lfribidi -lpng
# --------------------------- [ANTICONF] --------------------------------
# Configuration failed to find the --static harfbuzz freetype2 fribidi library. Try installing:
#  * deb: libharfbuzz-dev libfribidi-dev (Debian, Ubuntu, etc)
#  * rpm: harfbuzz-devel fribidi-devel (Fedora, EPEL)
#  * csw: libharfbuzz_dev libfribidi_dev (Solaris)
#  * brew: harfbuzz fribidi (OSX)
# If --static harfbuzz freetype2 fribidi is already installed, check that 'pkg-config' is in your
# PATH and PKG_CONFIG_PATH contains a --static harfbuzz freetype2 fribidi.pc file. If pkg-config
# is unavailable you can set INCLUDE_DIR and LIB_DIR manually via:
# R CMD INSTALL --configure-vars='INCLUDE_DIR=... LIB_DIR=...'
# -------------------------- [ERROR MESSAGE] ---------------------------
# <stdin>:1:10: fatal error: 'hb-ft.h' file not found
# #include <hb-ft.h>
#          ^~~~~~~~~
# 1 error generated.
# --------------------------------------------------------------------
# ERROR: configuration failed for package ‘textshaping’
# * removing ‘/opt/homebrew/lib/R/4.2/site-library/textshaping’
# ERROR: dependency ‘textshaping’ is not available for package ‘ragg’
# * removing ‘/opt/homebrew/lib/R/4.2/site-library/ragg’
# ERROR: dependency ‘ragg’ is not available for package ‘pkgdown’
# * removing ‘/opt/homebrew/lib/R/4.2/site-library/pkgdown’
# ERROR: dependency ‘pkgdown’ is not available for package ‘devtools’
# * removing ‘/opt/homebrew/lib/R/4.2/site-library/devtools’
# R[write to console]:
#
# R[write to console]:
# R[write to console]: The downloaded source packages are in
# 	‘/private/var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T/RtmplJ9GEe/downloaded_packages’
# R[write to console]:
# R[write to console]:
#
# R[write to console]: Installing package into ‘/opt/homebrew/lib/R/4.2/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: system (cmd0): /opt/homebrew/Cellar/r/4.2.2_1/lib/R/bin/R CMD INSTALL
#
# R[write to console]: trying URL 'http://cran.us.r-project.org/src/contrib/gridExtra_2.3.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1062844 bytes (1.0 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.0 MB
#
#
# R[write to console]: foundpkgs: gridExtra, /var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T//RtmplJ9GEe/downloaded_packages/gridExtra_2.3.tar.gz
#
# R[write to console]: files: /var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T//RtmplJ9GEe/downloaded_packages/gridExtra_2.3.tar.gz
#
# * installing *source* package ‘gridExtra’ ...
# ** package ‘gridExtra’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (gridExtra)
# R[write to console]: 1): succeeded '/opt/homebrew/Cellar/r/4.2.2_1/lib/R/bin/R CMD INSTALL -l '/opt/homebrew/lib/R/4.2/site-library' '/var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T//RtmplJ9GEe/downloaded_packages/gridExtra_2.3.tar.gz''
#
# R[write to console]:
#
# R[write to console]:
# R[write to console]: The downloaded source packages are in
# 	‘/private/var/folders/pt/jkchdrfd5yv20xq6r_krzwtr0000gn/T/RtmplJ9GEe/downloaded_packages’
# R[write to console]:
# R[write to console]:
# [[1]]
# NULL
#
# [[2]]
# NULL
#
# [[3]]
# NULL
#
# [[4]]
# NULL
#
# [[5]]
# NULL

# %%
# %%R
#
# sprintf("Successfully loaded: %s", libs)
# Out:
# [1] "Successfully loaded: tidyverse" "Successfully loaded: extrafont"
# [3] "Successfully loaded: Cairo"     "Successfully loaded: devtools"
# [5] "Successfully loaded: gridExtra"

# %% [markdown]
# # Exploratory data analysis
#
# So far we've done a lot of looking at distributions of single variables. In this dataset we have some continuous variables (like `mpg`, `disp`, `hp`, `drat`, `wt`, and `qsec`) and some discrete variables (like `vs`, `am`, `gear`, and `carb`). Let's quickly glance through the distributions of them.

# %%
# %%R
#
# continuous_variables <- c('mpg', 'disp', 'hp', 'drat', 'wt', 'qsec')
# discrete_variables   <- c('vs', 'am', 'gear', 'carb')
#
# # Conevert to long format
# mtcars_long = mtcars %>% pivot_longer(!name, names_to = 'variable', values_to = 'value')
#
# # plot only continuous variables
# to_plot <- mtcars_long %>% filter(variable %in% continuous_variables)
#
# histogram_means <- to_plot %>%
#   group_by(variable) %>%
#   summarise(mean = mean(value))
#
# plot_continuous_histograms <- ggplot(to_plot) +
#     aes(x=value, fill=variable, group=variable) +
#     geom_histogram(bins=5) +
#     geom_vline(data=histogram_means, aes(xintercept=mean)) +
#     facet_wrap(~variable, scales='free') +
#     theme_minimal() +
#     labs(title = 'mtcars at a glance', subtitle='continuous variables (means marked with a vertical line)')
#
#
# plot_continuous_dotplot <- ggplot(to_plot) +
#     aes(x=value, y=1, color=variable) +
#     geom_point(size=4, alpha=.2) +
#     stat_summary(fun.y= mean, geom="point", shape='x',
#                  size=10, color="black", alpha=1, orientation='y') +
#     facet_wrap(~variable, scales='free', ncol=1) +
#     theme_minimal() +
#     labs(
#         title = 'mtcars at a glance',
#         subtitle='continuous variables (means marked with an X)'
#     ) +
#     theme(
#             axis.text.y=element_blank(),  #remove y axis labels
#             axis.ticks.y=element_blank(),  #remove y axis ticks
#             panel.grid.major.y = element_blank(), #remove y axis grid
#             panel.grid.minor.y = element_blank(), #remove y axis grid
#     )
#
# #plot_continuous
#
# # display both plots
# print(plot_continuous_histograms)
# print(plot_continuous_dotplot)

# %%
# %%R
#
# # plot only discrete variables
# to_plot <- mtcars_long %>% filter(variable %in% discrete_variables)
#
# plot_discrete <- ggplot(to_plot) +
#     aes(y=value, fill=variable) +
#     geom_bar() +
#     facet_wrap(~variable, scales='free') +
#     theme_minimal() +
#     labs(title = 'mtcars at a glance', subtitle='discrete variables')
#
#
# plot_discrete

# %% [markdown]
# 👉 What can we conclude about this dataset from the charts above?

# %%
# answer here
# Cars in this dataset tend to skew less fuel efficient (around 20)
# Most cars are under 4000lbs, although there are some outliers in this.
# Most cars have 0-4 carbs, only very few have 6-8.

# %% [markdown]
# 👉 What can we not conclude about this dataset from the charts above?

# %%
# answer here
# We can't conclude which cars these are and can't conclude whether some specs of one car corresponds to certain values in the car's other specs

# %% [markdown]
# 👉 What further questions about this data do you have now?

# %%
# answer here
# Some cars (Maserati Bora) has high specs in hp, cyl, and carb. Could these things be correlated?

# %% [markdown]
# # Comparing variables to one another
#
# You're welcome to explore those univariate distributions more, but let's focus on something new. Comparing variables to one another. I'll start you off with a basic scatter plot.

# %%
# %%R
#
# ggplot(mtcars) +
#     aes(y=mpg, x=wt) +
#     geom_point() +
#     labs(title="Heavier cars tend to be less fuel efficient",
#     subtitle="Miles per gallon, by car weight") +
#     theme_minimal() +
#     xlab("car weight") + ylab("miles per gallon")

# %% [markdown]
# # 👉 Try It
#
# 1. Imporve the chart above. Add a title and subtitle, and better axis labels. Be **very careful** about the language you use in the headline. Assume you have a very strict copyeditor, make the language easy to understand but make sure you're not saying more than what the data proves.
#
# 2. Answer the questions below:
#
#     a. What can we conclude about fuel efficiency and weight
#     - We can conclude that there is a negative correlation between car weight and mpg/fuel efficiency.
#     - In other words, the higher the weight, generally the lower the fuel efficiency.
#
#     b. What can't we conclude about fuel efficiency and weight
#     - We can't say that one causes the other or vice versa. There could be other confounding factors.
#
#     c. What further questions do you have about this data?
#     - What else might affect fuel efficiency/or is correlated with fuel efficiency?

# %% [markdown]
# ## Part 1 (Gudied Inquiry)
# # 👉 What makes cars more fuel efficient?

# %%
# %%R
#
# ggplot(mtcars) +
#     aes(y=mpg, x=cyl) +
#     geom_point() +
#     labs(title="Cars with fewer cylinders tend to be more fuel efficient",
#     subtitle="Miles per gallon, by number of cylinders") +
#     theme_minimal() +
#     xlab("cylinders") + ylab("miles per gallon")

# %%
# %%R
#
# ggplot(mtcars) +
#     aes(y=mpg, x=disp) +
#     geom_point() +
#     labs(title="Cars with lower displacement tend to be more fuel efficient",
#     subtitle="Miles per gallon, by displacement") +
#     theme_minimal() +
#     xlab("displacement") + ylab("miles per gallon")

# %%
# %%R
#
# ggplot(mtcars) +
#     aes(y=mpg, x=hp) +
#     geom_point() +
#     labs(title="",
#     subtitle="") +
#     theme_minimal() +
#     xlab("horse power") + ylab("miles per gallon")

# %%
# %%R
#
# ggplot(mtcars) +
#     aes(y=mpg, x=drat) +
#     geom_point() +
#     labs(title="",
#     subtitle="Miles per gallon, by rear axle ratio") +
#     theme_minimal() +
#     xlab("rear axle ratio") + ylab("miles per gallon")

# %%
# %%R
#
# ggplot(mtcars) +
#     aes(y=mpg, x=qsec) +
#     geom_point() +
#     labs(title="",
#     subtitle="") +
#     theme_minimal() +
#     xlab("qsec") + ylab("miles per gallon")

# %%
# %%R
#
# ggplot(mtcars) +
#     aes(y=mpg, x=vs) +
#     geom_point() +
#     labs(title="",
#     subtitle="") +
#     theme_minimal() +
#     xlab("vs") + ylab("miles per gallon")

# %%
# %%R
#
# ggplot(mtcars) +
#     aes(y=mpg, x=am) +
#     geom_point() +
#     labs(title="",
#     subtitle="") +
#     theme_minimal() +
#     xlab("am") + ylab("miles per gallon")

# %%
# %%R
#
# ggplot(mtcars) +
#     aes(y=mpg, x=gear) +
#     geom_point() +
#     labs(title="",
#     subtitle="") +
#     theme_minimal() +
#     xlab("gear") + ylab("miles per gallon")

# %%
# %%R
#
# ggplot(mtcars) +
#     aes(y=mpg, x=carb) +
#     geom_point() +
#     labs(title="",
#     subtitle="") +
#     theme_minimal() +
#     xlab("carb") + ylab("miles per gallon")

# %% [markdown]
# ## Part 2 (freeform inquiry)
# Ask and try to answer your own questions about the dataset. Make at least two such charts below:

# %% [markdown]
# # 👉 Question 1:
#
# Is anything correlated to drat? What makes it high/low?

# %% [markdown]
# ### 👉 Charts or summary statistics to help answer your question

# %%
# %%R
#
# ggplot(mtcars) +
#     aes(y=drat, x=wt, color=am) +
#     geom_point() +
#     labs(title="",
#     subtitle="") +
#     theme_minimal() +
#     xlab("") + ylab("")
#
# # ggplot code here

# %%
# %%R
#
# ggplot(mtcars) +
#     aes(y=drat, x=wt, color=mpg) +
#     geom_point() +
#     labs(title="",
#     subtitle="") +
#     theme_minimal() +
#     xlab("") + ylab("")

# %% [markdown]
# ### 👉 Reflection
#
# a. What can we conclude?
# - I can conclude from the graphs above that drat is negatively correlated with weight and positively correlated with mpg.
#
# b. What can't we conclude?
# - I cannot conclude any causal relationships, because in the previous exploration, we see that mpg is negatively correlated with weight, which gives anything positively correlated with mpg a negative correlation with weight.
#
# c. What further questions does this analysis raise?
# - What about a car would affect its drat? What are the confounding variables that we can control for (ie facet wrap) to further explore the dataset (in this case we can't facet wrap a lot of the continuous variables.)
